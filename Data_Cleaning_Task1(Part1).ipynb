# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"D:\downloads\Unclean Dataset.csv", encoding="ISO-8859-1")
df= df.round()
print(df)
# Out:
#                                            Student_ID   First_Name   \
# 0    101        | John       | Smith     | 22  | M ...          NaN
# 1    102        | Emily      | Johnson   | 24  | F ...          NaN
# 2    103        | Michael    | Williams  | 21  | M ...          NaN
# 3    104        | Sarah      | Brown     | 23  | F ...          NaN
# 4    105        | David      | Davis     | 20  | M ...          NaN
# ..                                                 ...          ...
# 131  232        | Amina      | Adekunle    | 21  | ...          NaN
# 132  234       | Ibrahim    | Okafor      | 22  | M...          NaN
# 133  235        | Zainab     | Abiodun     | 23  | ...          NaN
# 134  236        | Nasiru     | Adebayo     | 24  | ...          NaN
# 135  237       | Aisha      | Okonkwo     | 25  | F...          NaN
#
#      Last_Name   Age   Gender   Course   Enrollment_Date   Total_Payments
# 0           NaN   NaN      NaN      NaN               NaN             NaN
# ...

# %%
df.head()
# Out:
#                                          Student_ID   First_Name   Last_Name   \
# 0  101        | John       | Smith     | 22  | M ...          NaN         NaN
# 1  102        | Emily      | Johnson   | 24  | F ...          NaN         NaN
# 2  103        | Michael    | Williams  | 21  | M ...          NaN         NaN
# 3  104        | Sarah      | Brown     | 23  | F ...          NaN         NaN
# 4  105        | David      | Davis     | 20  | M ...          NaN         NaN
#
#    Age   Gender   Course   Enrollment_Date   Total_Payments
# 0   NaN      NaN      NaN               NaN             NaN
# 1   NaN      NaN      NaN               NaN             NaN
# 2   NaN      NaN      NaN               NaN             NaN
# 3   NaN      NaN      NaN               NaN             NaN
# 4   NaN      NaN      NaN               NaN             NaN

# %%
df.columns.to_list()
# Out:
# ['Student_ID ',
#  ' First_Name ',
#  ' Last_Name ',
#  ' Age ',
#  ' Gender ',
#  ' Course ',
#  ' Enrollment_Date ',
#  ' Total_Payments']

# %%
print(df.loc[116, 'Student_ID '])
# Out:
# 217       | Chukwudi   |     | 22  | M      | Data Science     | 2022-05-15      | $1200

# %%
df.tail(45)
# Out:
#                                            Student_ID          First_Name   \
# 91                                      Zainab Adeyemi      Zainab Adeyemi
# 92                                       Obinna Onwuka       Obinna Onwuka
# 93                                        Amina Osagie        Amina Osagie
# 94                                       Chinonso Uche       Chinonso Uche
# 95                                      Femi Abdullahi      Femi Abdullahi
# 96                                       Halima Bakare       Halima Bakare
# 97                                    Chibuzo Mohammed    Chibuzo Mohammed
# 98                                       Oluchi Iwuoha       Oluchi Iwuoha
# 99                                     Emeka Anikulapo     Emeka Anikulapo
# 100                                    Hadiza Ogundipe     Hadiza Ogundipe
# 101                                    Nneka Nwachukwu     Nneka Nwachukwu
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Student_ID         132 non-null    object
#  1    First_Name        99 non-null     object
#  2    Last_Name         18 non-null     object
#  3    Age               53 non-null     object
#  4    Gender            59 non-null     object
#  5    Course            54 non-null     object
#  6    Enrollment_Date   60 non-null     object
#  7    Total_Payments    58 non-null     object
# dtypes: object(8)
# memory usage: 8.6+ KB

# %%
df
df[df[' Age '] > "21"]
# Out:
#             Student_ID          First_Name   Last_Name   Age   Gender   \
# 20              Ayodele             Ayodele         NaN     F       18
# 21                  NaN                 NaN         NaN     M       25
# 22                  NaN                 NaN         NaN     F       25
# 35              Joseph              Joseph     Williams    22     F 24
# 36               Kylian              Kylian        Eden   78*        M
# 37               Esther              Esther       Naomi   21*        F
# 38                  Lay                 Lay      Martin    22        M
# 39                 Rock                Rock         Shy    23        M
# 70             Adeniran            Adeniran    Omoshola    22        F
# 71              Iwueze              Iwueze     Olaoluwa    23        M
# 72      Faramotu Ismail     Faramotu Ismail         NaN    23        M
# 73              Ifarele             Ifarele      Adeola    23        M
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Student_ID         132 non-null    object
#  1    First_Name        99 non-null     object
#  2    Last_Name         18 non-null     object
#  3    Age               53 non-null     object
#  4    Gender            59 non-null     object
#  5    Course            54 non-null     object
#  6    Enrollment_Date   60 non-null     object
#  7    Total_Payments    58 non-null     object
# dtypes: object(8)
# memory usage: 8.6+ KB

# %%
df_clean= df.dropna() ## Here I decided to remove that rows because its too messy not have pattern need to chech each row by itself and thats not efficient so decided to remove them as wrong data and keep that has useful info. ##
df_clean
# Out:
#    Student_ID   First_Name   Last_Name   Age   Gender            Course   \
# 35     Joseph       Joseph     Williams    22     F 24  Machine Learning
# 36      Kylian       Kylian        Eden   78*        M  Machine Learning
# 37      Esther       Esther       Naomi   21*        F  Machine Learning
# 38         Lay          Lay      Martin    22        M    Web Developmet
# 70    Adeniran     Adeniran    Omoshola    22        F     Data Analysis
# 71     Iwueze       Iwueze     Olaoluwa    23        M     Data Analysis
# 73     Ifarele      Ifarele      Adeola    23        M     Data Analysis
# 74  Folorunsho   Folorunsho        Dada    22        M   Web Development
# 75   Ikechukwu    Ikechukwu      Victor    22        M   Web Development
# 76       Ahmed        Ahmed    Mohammed    23        F   Web Development
# 77       Binta        Binta       Sanni    22        F   Web Development
# 78      Chukwu       Chukwu         Ike    22        M   Web Development
# ...

# %%
print(df_clean.columns.tolist())
# Out:
# ['Student_ID ', ' First_Name ', ' Last_Name ', ' Age ', ' Gender ', ' Course ', ' Enrollment_Date ', ' Total_Payments']

# %%
df_clean.value_counts()
# Out:
# Student_ID    First_Name    Last_Name    Age    Gender    Course            Enrollment_Date    Total_Payments
#  Okafor       Okafor       Chike        23     M         Data Analysis     11-Jul-20           ? 129,687         1
# Adeniran     Adeniran      Omoshola     22     F         Data Analysis     01-Jul-21          50000              1
# Ahmed        Ahmed         Mohammed     23     F         Web Development   19-Jul-21           ? 88,578          1
# Binta        Binta         Sanni        22     F         Web Development   01-Jul-21           ? 97,436          1
# Chukwu       Chukwu        Ike          22     M         Web Development   01-Jul-22           ? 107,179         1
# Esther       Esther        Naomi        21*    F         Machine Learning  08-01-22           £20,000            1
# Folorunsho   Folorunsho    Dada         22     M         Web Development   01-Jul-22           ? 73,205          1
# ...

# %%
df_clean[' Total_Payments']= (df_clean[' Total_Payments'].astype(str).str.replace(r"[^\d]", "", regex=True).astype(int)).apply(lambda x: f"${x:,}")
df_clean
# Out:
# C:\Users\oasm2\AppData\Local\Temp\ipykernel_14424\973614148.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean[' Total_Payments']= (df_clean[' Total_Payments'].astype(str).str.replace(r"[^\d]", "", regex=True).astype(int)).apply(lambda x: f"${x:,}")
#    Student_ID   First_Name   Last_Name   Age   Gender            Course   \
# 35     Joseph       Joseph     Williams    22     F 24  Machine Learning
# 36      Kylian       Kylian        Eden   78*        M  Machine Learning
# 37      Esther       Esther       Naomi   21*        F  Machine Learning
# 38         Lay          Lay      Martin    22        M    Web Developmet
# 70    Adeniran     Adeniran    Omoshola    22        F     Data Analysis
# ...

# %%
df_clean[" Age "]=(df_clean[" Age "].astype(str).str.replace(r'[^\d]', "", regex=True).astype(int))
df_clean
# Out:
# C:\Users\oasm2\AppData\Local\Temp\ipykernel_14424\1290360966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean[" Age "]=(df_clean[" Age "].astype(str).str.replace(r'[^\d]', "", regex=True).astype(int))
#    Student_ID   First_Name   Last_Name    Age   Gender            Course   \
# 35     Joseph       Joseph     Williams     22     F 24  Machine Learning
# 36      Kylian       Kylian        Eden     78        M  Machine Learning
# 37      Esther       Esther       Naomi     21        F  Machine Learning
# 38         Lay          Lay      Martin     22        M    Web Developmet
# 70    Adeniran     Adeniran    Omoshola     22        F     Data Analysis
# ...

# %%
df_clean[" Gender "]=(df_clean[" Gender "].astype(str).str.replace(r"\d", "", regex=True).astype(str))
df_clean
# Out:
# C:\Users\oasm2\AppData\Local\Temp\ipykernel_14424\2724720338.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean[" Gender "]=(df_clean[" Gender "].astype(str).str.replace(r"\d", "", regex=True).astype(str))
#    Student_ID   First_Name   Last_Name    Age   Gender            Course   \
# 35     Joseph       Joseph     Williams     22       F   Machine Learning
# 36      Kylian       Kylian        Eden     78        M  Machine Learning
# 37      Esther       Esther       Naomi     21        F  Machine Learning
# 38         Lay          Lay      Martin     22        M    Web Developmet
# 70    Adeniran     Adeniran    Omoshola     22        F     Data Analysis
# ...

# %%
df_clean.index =df_clean.reset_index(drop=True).index + 1
df_clean
# Out:
#    Student_ID   First_Name   Last_Name    Age   Gender            Course   \
# 1      Joseph       Joseph     Williams     22       F   Machine Learning
# 2       Kylian       Kylian        Eden     78        M  Machine Learning
# 3       Esther       Esther       Naomi     21        F  Machine Learning
# 4          Lay          Lay      Martin     22        M    Web Developmet
# 5     Adeniran     Adeniran    Omoshola     22        F     Data Analysis
# 6      Iwueze       Iwueze     Olaoluwa     23        M     Data Analysis
# 7      Ifarele      Ifarele      Adeola     23        M     Data Analysis
# 8   Folorunsho   Folorunsho        Dada     22        M   Web Development
# 9    Ikechukwu    Ikechukwu      Victor     22        M   Web Development
# 10       Ahmed        Ahmed    Mohammed     23        F   Web Development
# 11       Binta        Binta       Sanni     22        F   Web Development
# 12      Chukwu       Chukwu         Ike     22        M   Web Development
# ...

# %%
df_clean=df_clean.drop('Student_ID ', axis=1)
df_clean
# Out:
#    First_Name  Last_Name   Age  Gender            Course  Enrollment_Date   \
# 1      Joseph    Williams    22      F   Machine Learning         08-01-23
# 2       Kylian       Eden    78       M  Machine Learning         08-01-24
# 3       Esther      Naomi    21       F  Machine Learning         08-01-22
# 4          Lay     Martin    22       M    Web Developmet         08-01-24
# 5     Adeniran   Omoshola    22       F     Data Analysis        01-Jul-21
# 6      Iwueze    Olaoluwa    23       M     Data Analysis        10-Jul-20
# 7      Ifarele     Adeola    23       M     Data Analysis        30-Aug-22
# 8   Folorunsho       Dada    22       M   Web Development        01-Jul-22
# 9    Ikechukwu     Victor    22       M   Web Development        01-Jul-24
# 10       Ahmed   Mohammed    23       F   Web Development        19-Jul-21
# 11       Binta      Sanni    22       F   Web Development        01-Jul-21
# ...
